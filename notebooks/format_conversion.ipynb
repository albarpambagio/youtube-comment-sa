# %%
import pandas as pd

# %%
df = pd.read_json('SzXMacu80o8.json', lines=True)

# %%
df.head()
# Out:
#                           cid  \
# 0  UgwpwnguiQOb1w0lPyJ4AaABAg
# 1  Ugw8wqCdnuHpJATtMrB4AaABAg
# 2  UgwEGxoBS0Bn2pS2t4t4AaABAg
# 3  UgyIxvq18sSdDqhWdRh4AaABAg
# 4  Ugy_ym5PvM-fkCFMTPF4AaABAg
#
#                                                 text                time  \
# 0  Pinjol judol noh urusin...biar ada manfaatnya ...   2 menit yang lalu
# 1  Percuma 208 juta penduduk dalam usia produktif...  13 menit yang lalu
# 2                                        TOMBOL BEGO  13 menit yang lalu
# 3  Anehnya spam judol ogah nongol dimarih...saket...  15 menit yang lalu
# 4  Ok pak generasi muda udah siap, tinggal kabine...  20 menit yang lalu
#
#                 author                   channel  votes replies  \
# 0  @zoelldelarocha3314  UCjpKB1JH4Bvx1jpQPy_so4A      1
# 1            @damnwho_  UCJAgAtmVy5y0s1Q5zJ9toSg      0
# 2    @AkunServerMaxMAX  UCYMxaL3r0Xvd1XcspuySOtQ      0
# 3  @zoelldelarocha3314  UCjpKB1JH4Bvx1jpQPy_so4A      1
# ...

# %%
# Get 500 random rows from the 'text' column
sample_label = df['text'].sample(n=500, random_state=42)  # random_state ensures reproducibility

# Save to CSV
sample_label.to_csv('random_sample_text.csv', index=False)

# %%
df['text'].to_csv('full_text.csv', index=False)
